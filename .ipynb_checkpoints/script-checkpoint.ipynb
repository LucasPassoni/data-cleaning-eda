# %%
#Data Data Cleaning and Exploratory Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.float_format = '{:.2f}'.format #para os números aparecerem com duas casas decimais
pd.set_option('display.max_columns', 50) #mostra 50 colunas ou o número desejado
pd.set_option('future.no_silent_downcasting', True)

dados = pd.read_excel("dados-2016-2021.xlsx", decimal=',')
dados.shape

#salvando os dados de 2021
dados21 = dados[dados['ANO_APOLICE'] == 2021]
dados21.shape

#Cada uma das 212839 linhas, é uma apólice contratada por um produtor. 

dados21.head

#cópia de segurança (copy of our database), vamos trabalhar com uma cópia dos dados, não com o conjunto original
seg = dados21.copy()

seg.head()

seg.tail()

seg.sample(10)

seg.columns #mostra as variáveis que temos no conjunto de dados

seg.info() #algumas variáveis, como DT_FIM_VIGENCIA vão precisar ter o seu dtype alterado. 

#FILTRANDO LINHAS #fazendo apenas consultas na base
#aqui vamos usar principalmente o método iloc
#iloc: que é utilizado para selecionar linhas e colunas, a partir de sua posição inteira
#loc: e não a partir dos rótulos ou nomes das linhas/colunas 

seg.iloc[:20, :10] #os dois pontos indicam toda a coluna

seg['NM_CULTURA_GLOBAL'].unique() #verificando quais tipos de culturas


seg['NM_MUNICIPIO_PROPRIEDADE'].unique() #verificando quantos municipios

seg['SG_UF_PROPRIEDADE'].unique() #verificando os estados

#selecionando a partir do nome da coluna
seg.loc[:, ['NR_AREA_TOTAL', 'NR_PRODUTIVIDADE_ESTIMADA', 'VL_LIMITE_GARANTIA', 
            'VL_PREMIO_LIQUIDO', 'VL_SUBVENCAO_FEDERAL', 'NR_APOLICE', 'NM_CULTURA_GLOBAL']]
 

#selecionando o estado do PR
seg_pr = seg.loc[seg['SG_UF_PROPRIEDADE'] == 'PR'] 

#principais culturas seguradas do Estado do PR
seg_pr['NM_CULTURA_GLOBAL'].unique()

#salvando os dados do meu município
seg_maringa = seg.loc[seg['NM_MUNICIPIO_PROPRIEDADE'] == 'Maringá'] 

#principais safras seguradas do meu municipio
seg_maringa['NM_CULTURA_GLOBAL'].unique() 

#poderíamos usar o query também
seg.query('(NM_MUNICIPIO_PROPRIEDADE == "Maringá") and (NM_CULTURA_GLOBAL == "Soja")')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 212839 entries, 484614 to 697452
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   NM_RAZAO_SOCIAL            212839 non-null  object
#  1   CD_PROCESSO_SUSEP          212839 non-null  int64
#  2   NR_PROPOSTA                212839 non-null  object
#  3   ID_PROPOSTA                212839 non-null  int64
#  4   DT_PROPOSTA                212839 non-null  datetime64[ns]
#  5   DT_INICIO_VIGENCIA         212839 non-null  datetime64[ns]
#  6   DT_FIM_VIGENCIA            212839 non-null  object
#  7   NM_SEGURADO                212839 non-null  object
#  8   NR_DOCUMENTO_SEGURADO      212839 non-null  object
#  9   NM_MUNICIPIO_PROPRIEDADE   212839 non-null  object
#  10  SG_UF_PROPRIEDADE          212839 non-null  object
#  11  LATITUDE                   212839 non-null  object
#  12  NR_GRAU_LAT                212839 non-null  int64
#  13  NR_MIN_LAT                 212839 non-null  int64
#  14  NR_SEG_LAT                 212839 non-null  int64
#  15  LONGITUDE                  212839 non-null  object
#  16  NR_GRAU_LONG               212839 non-null  int64
#  17  NR_MIN_LONG                212839 non-null  int64
#  18  NR_SEG_LONG                212839 non-null  int64
#  19  NR_DECIMAL_LATITUDE        212839 non-null  object
#  20  NR_DECIMAL_LONGITUDE       212839 non-null  object
#  21  NM_CLASSIF_PRODUTO         212839 non-null  object
#  22  NM_CULTURA_GLOBAL          212839 non-null  object
#  23  NR_AREA_TOTAL              212839 non-null  float64
#  24  NR_ANIMAL                  212839 non-null  object
#  25  NR_PRODUTIVIDADE_ESTIMADA  212839 non-null  object
#  26  NR_PRODUTIVIDADE_SEGURADA  212839 non-null  object
#  27  NivelDeCobertura           212839 non-null  object
#  28  VL_LIMITE_GARANTIA         212839 non-null  float64
#  29  VL_PREMIO_LIQUIDO          212839 non-null  float64
#  30  PE_TAXA                    212839 non-null  float64
#  31  VL_SUBVENCAO_FEDERAL       212839 non-null  float64
#  32  NR_APOLICE                 212839 non-null  object
#  33  DT_APOLICE                 212839 non-null  datetime64[ns]
#  34  ANO_APOLICE                212839 non-null  int64
#  35  CD_GEOCMU                  212839 non-null  object
#  36  VALOR_INDENIZAÇÃO          212839 non-null  object
#  37  EVENTO_PREPONDERANTE       212839 non-null  object
# dtypes: datetime64[ns](3), float64(5), int64(9), object(21)
# memory usage: 63.3+ MB
#                        NM_RAZAO_SOCIAL  CD_PROCESSO_SUSEP NR_PROPOSTA  \
# 524955             Allianz Seguros S.A  15414002759200717   116373451
# 524992             Allianz Seguros S.A  15414002759200717   116373742
# 525004             Allianz Seguros S.A  15414002759200717   116373896
# 525013             Allianz Seguros S.A  15414002759200717   116374031
# 525026             Allianz Seguros S.A  15414002759200717   116374411
# ...                                ...                ...         ...
# 680783  BRASILSEG COMPANHIA DE SEGUROS  15414609027202020   263607701
# 680896  BRASILSEG COMPANHIA DE SEGUROS  15414001668201141   267035090
# 683343  BRASILSEG COMPANHIA DE SEGUROS  15414001668201141   264309973
# 683787  BRASILSEG COMPANHIA DE SEGUROS  15414001668201141   266665058
# 690356  BRASILSEG COMPANHIA DE SEGUROS  15414609027202020   264580490
#
#         ID_PROPOSTA DT_PROPOSTA DT_INICIO_VIGENCIA      DT_FIM_VIGENCIA  \
# 524955      1335705  2021-05-26         2021-09-15  2022-04-03 00:00:00
# 524992      1335742  2021-05-26         2021-09-15  2022-04-03 00:00:00
# 525004      1335754  2021-05-26         2021-09-15  2022-04-03 00:00:00
# 525013      1335765  2021-05-26         2021-09-15  2022-04-03 00:00:00
# 525026      1335778  2021-05-26         2021-09-15  2022-04-03 00:00:00
# ...             ...         ...                ...                  ...
# 680783      1507272  2021-04-09         2021-04-09  2022-04-09 00:00:00
# 680896      1507387  2021-10-19         2021-10-19  2022-10-19 00:00:00
# 683343      1509915  2021-05-24         2021-05-24  2022-05-24 00:00:00
# 683787      1510362  2021-09-28         2021-09-28  2022-09-28 00:00:00
# 690356      1517028  2021-06-09         2021-06-09  2022-06-09 00:00:00
#
#                              NM_SEGURADO NR_DOCUMENTO_SEGURADO  \
# 524955  PATRICK ALEXANDRE CONEJO BORTOLO           ***10734982
# 524992  PATRICK ALEXANDRE CONEJO BORTOLO           ***10734982
# 525004  PATRICK ALEXANDRE CONEJO BORTOLO           ***10734982
# 525013  PATRICK ALEXANDRE CONEJO BORTOLO           ***10734982
# 525026            ADRIANA RAFAEL BORTOLO           ***03860926
# ...                                  ...                   ...
# 680783          MARCELO VINICIUS ARANTES           ***13551900
# 680896    JOSUE FAGUNDES VERDERIO JUNIOR           ***63198991
# 683343     MARIA IZABEL RODRIGUES MUNHOZ           ***45990912
# 683787               NELIDA CREMM PAVESI           ***11010900
# 690356                 VITOR JOSE BORGHI           ***45900927
#
#        NM_MUNICIPIO_PROPRIEDADE SG_UF_PROPRIEDADE LATITUDE  NR_GRAU_LAT  \
# 524955                  Maringá                PR        S           23
# 524992                  Maringá                PR        S           23
# 525004                  Maringá                PR        S           23
# 525013                  Maringá                PR        S           23
# 525026                  Maringá                PR        S           23
# ...                         ...               ...      ...          ...
# 680783                  Maringá                PR        S           23
# 680896                  Maringá                PR        S           23
# 683343                  Maringá                PR        S           23
# 683787                  Maringá                PR        S           23
# 690356                  Maringá                PR        S           23
#
#         NR_MIN_LAT  NR_SEG_LAT LONGITUDE  NR_GRAU_LONG  NR_MIN_LONG  \
# 524955          21          32         W            52            2
# 524992          21           1         W            52            2
# 525004          20          50         W            52            3
# 525013          24           2         W            52            1
# 525026          24           0         W            52            3
# ...            ...         ...       ...           ...          ...
# 680783          27          53         W            51           55
# 680896          30          11         W            52            2
# 683343          19          37         W            52            1
# 683787          20          37         W            51           58
# 690356          31          20         W            52            0
#
#         NR_SEG_LONG NR_DECIMAL_LATITUDE NR_DECIMAL_LONGITUDE  \
# 524955            4                   -                    -
# 524992           44                   -                    -
# 525004           16                   -                    -
# 525013           28                   -                    -
# 525026           18                   -                    -
# ...             ...                 ...                  ...
# 680783           12                   -                    -
# 680896           57                   -                    -
# 683343            7                   -                    -
# 683787           17                   -                    -
# 690356            6                   -                    -
#
#        NM_CLASSIF_PRODUTO NM_CULTURA_GLOBAL  NR_AREA_TOTAL NR_ANIMAL  \
# 524955      PRODUTIVIDADE              Soja          38.72         0
# 524992      PRODUTIVIDADE              Soja          29.04         0
# 525004      PRODUTIVIDADE              Soja          10.89         0
# 525013      PRODUTIVIDADE              Soja          12.10         0
# 525026      PRODUTIVIDADE              Soja          25.00         0
# ...                   ...               ...            ...       ...
# 680783            CUSTEIO              Soja         140.00         -
# 680896            CUSTEIO              Soja          47.00         -
# 683343            CUSTEIO              Soja          36.30         -
# 683787            CUSTEIO              Soja          60.50         -
# 690356            CUSTEIO              Soja          90.00         -
#
#        NR_PRODUTIVIDADE_ESTIMADA NR_PRODUTIVIDADE_SEGURADA NivelDeCobertura  \
# 524955                   3787.41                   2461.82             0.65
# 524992                   3787.41                   2461.82             0.65
# 525004                   3787.41                   2461.82             0.65
# 525013                   3787.41                   2461.82             0.65
# 525026                   3787.41                   2461.82             0.65
# ...                          ...                       ...              ...
# 680783                      3597                   2517.90             0.70
# 680896                      3100                      2170             0.70
# 683343                      3652                   2556.40             0.70
# 683787                      3560                      2492             0.70
# 690356                      3652                   2556.40             0.70
#
#         VL_LIMITE_GARANTIA  VL_PREMIO_LIQUIDO  PE_TAXA  VL_SUBVENCAO_FEDERAL  \
# 524955           223052.76           11211.09     0.05               2242.21
# 524992           167289.57            8408.33     0.05               1681.66
# 525004            62733.59            3153.10     0.05                630.61
# 525013            69703.99            3503.43     0.05                700.68
# 525026           144016.50            7238.56     0.05               1447.70
# ...                    ...                ...      ...                   ...
# 680783           344723.16           32411.47     0.09               6482.29
# 680896           326500.82           25440.28     0.08               5088.06
# 683343           489739.82           17205.12     0.04               3441.02
# 683787           466018.64           39172.79     0.08               7834.56
# 690356           231219.02           20652.63     0.09               4130.53
#
#                  NR_APOLICE DT_APOLICE  ANO_APOLICE CD_GEOCMU  \
# 524955  5177202135010003619 2021-05-27         2021   4115200
# 524992  5177202135010003618 2021-05-27         2021   4115200
# 525004  5177202135010003617 2021-05-27         2021   4115200
# 525013  5177202135010003616 2021-05-27         2021   4115200
# 525026  5177202135010003615 2021-05-27         2021   4115200
# ...                     ...        ...          ...       ...
# 680783               132447 2021-04-22         2021   4115200
# 680896               186197 2021-10-25         2021   4115200
# 683343               141671 2021-05-26         2021   4115200
# 683787               181710 2021-09-30         2021   4115200
# 690356               146556 2021-06-18         2021   4115200
#
#        VALOR_INDENIZAÇÃO      EVENTO_PREPONDERANTE
# 524955         100847.58                      SECA
# 524992          45591.56                      SECA
# 525004                 0                      SECA
# 525013          35182.79                      SECA
# 525026          75431.16                      SECA
# ...                  ...                       ...
# 680783          94419.67                      SECA
# 680896         239216.23                      SECA
# 683343          70333.90   INUNDAÇÃO/TROMBA D´ÁGUA
# 683787         146899.99           CHUVA EXCESSIVA
# 690356         146091.95                      SECA
#
# [319 rows x 38 columns]

# %%
#Resumindo os dados

seg.describe()
# Out:
#          CD_PROCESSO_SUSEP  ID_PROPOSTA                    DT_PROPOSTA  \
# count            212839.00    212839.00                         212839
# mean  15414423377698950.00   1408981.47  2021-06-15 18:28:28.502671104
# min   15414000338200590.00   1289687.00            2020-07-17 00:00:00
# 25%   15414004195201052.00   1349849.50            2021-04-13 00:00:00
# 50%   15414609027202020.00   1409652.00            2021-07-01 00:00:00
# 75%   15414900270201600.00   1468900.50            2021-08-17 00:00:00
# max   15414901782201416.00   1524283.00            2021-12-23 00:00:00
# std        412730730553.47     68204.95                            NaN
#
#                   DT_INICIO_VIGENCIA  NR_GRAU_LAT  NR_MIN_LAT  NR_SEG_LAT  \
# count                         212839    212839.00   212839.00   212839.00
# mean   2021-06-23 12:01:20.173276672        23.35       28.74       29.19
# min              2020-07-17 00:00:00         0.00        0.00        0.00
# 25%              2021-04-19 00:00:00        22.00       13.00       14.00
# 50%              2021-07-07 00:00:00        24.00       28.00       29.00
# 75%              2021-08-30 00:00:00        26.00       44.00       44.00
# max              2022-04-02 00:00:00        33.00       93.00       99.00
# std                              NaN         4.21       17.71       17.54
#
#        NR_GRAU_LONG  NR_MIN_LONG  NR_SEG_LONG  NR_AREA_TOTAL  \
# count     212839.00    212839.00    212839.00      212839.00
# mean          50.61        29.39        29.32          64.30
# min           34.00         0.00         0.00           0.00
# 25%           49.00        14.00        14.00          12.42
# 50%           51.00        30.00        29.00          30.00
# 75%           53.00        44.00        45.00          71.80
# max           70.00        66.00        98.00      290985.00
# std            3.11        17.32        17.55         672.28
#
#        VL_LIMITE_GARANTIA  VL_PREMIO_LIQUIDO   PE_TAXA  VL_SUBVENCAO_FEDERAL  \
# count           212839.00          212839.00 212839.00             212839.00
# mean            312463.30           19397.15      0.08               5416.18
# min                753.48              55.34      0.00                  0.01
# 25%              71916.99            4960.00      0.05               1499.85
# 50%             150027.47           10239.68      0.07               3147.74
# 75%             338111.80           22598.85      0.10               6540.79
# max          520323520.32          893218.14      1.00              48000.00
# std            1374670.95           27293.34      0.04               6703.20
#
#                           DT_APOLICE  ANO_APOLICE
# count                         212839    212839.00
# mean   2021-06-30 01:20:21.762928896      2021.00
# min              2021-01-01 00:00:00      2021.00
# 25%              2021-04-27 00:00:00      2021.00
# 50%              2021-07-15 00:00:00      2021.00
# 75%              2021-08-31 00:00:00      2021.00
# max              2021-12-28 00:00:00      2021.00
# std                              NaN         0.00

# %%
medidas_resumo1 = seg[['VL_PREMIO_LIQUIDO', 'VL_SUBVENCAO_FEDERAL']].quantile([0.25, 0.5, 0.75])
medidas_resumo1
# Out:
#       VL_PREMIO_LIQUIDO  VL_SUBVENCAO_FEDERAL
# 0.25            4960.00               1499.85
# 0.50           10239.68               3147.74
# 0.75           22598.85               6540.79

# %%
plt.figure(figsize=(5, 2.7), layout='constrained')
plt.plot(medidas_resumo1, label = 'linear')
# Out:
# [<matplotlib.lines.Line2D at 0x20c8882f4d0>,
#  <matplotlib.lines.Line2D at 0x20c88863610>]

# %%
fig1, ax1 = plt.subplots()
ax1.set_title("Medidas Resumo: Premio Liquido e Subvenção Federal")
ax1.boxplot(medidas_resumo1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20c888fe0d0>,
#   <matplotlib.lines.Line2D at 0x20c888fe210>,
#   <matplotlib.lines.Line2D at 0x20c888fe990>,
#   <matplotlib.lines.Line2D at 0x20c888fead0>],
#  'caps': [<matplotlib.lines.Line2D at 0x20c888fe350>,
#   <matplotlib.lines.Line2D at 0x20c888fe490>,
#   <matplotlib.lines.Line2D at 0x20c888fec10>,
#   <matplotlib.lines.Line2D at 0x20c888fed50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x20c888fdf90>,
#   <matplotlib.lines.Line2D at 0x20c888fe850>],
#  'medians': [<matplotlib.lines.Line2D at 0x20c888fe5d0>,
#   <matplotlib.lines.Line2D at 0x20c888fee90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20c888fe710>,
#   <matplotlib.lines.Line2D at 0x20c888fefd0>],
#  'means': []}

# %%
medidas_resumo2 = seg[['VL_PREMIO_LIQUIDO', 'VL_SUBVENCAO_FEDERAL', 'VL_LIMITE_GARANTIA', 'NR_AREA_TOTAL']].agg(['mean', 'min', 'max'])
medidas_resumo2
# Out:
#       VL_PREMIO_LIQUIDO  VL_SUBVENCAO_FEDERAL  VL_LIMITE_GARANTIA  \
# mean           19397.15               5416.18           312463.30
# min               55.34                  0.01              753.48
# max           893218.14              48000.00        520323520.32
#
#       NR_AREA_TOTAL
# mean          64.30
# min            0.00
# max       290985.00

# %%
#seguradoras
seg['NM_RAZAO_SOCIAL'].unique()
# Out:
# array(['Newe Seguros S.A', 'BRASILSEG COMPANHIA DE SEGUROS',
#        'Mapfre Seguros Gerais S.A.',
#        'FairFax Brasil Seguros Corporativos S/A', 'Too Seguros S.A.',
#        'Tokio Marine Seguradora S.A.',
#        'Swiss Re Corporate Solutions Brasil S.A.', 'Allianz Seguros S.A',
#        'Sancor Seguros do Brasil S.A.', 'Aliança do Brasil Seguros S/A.',
#        'Essor Seguros S.A.', 'Porto Seguro Companhia de Seguros Gerais',
#        'Companhia Excelsior de Seguros', 'Sompo Seguros S/A',
#        'EZZE Seguros S.A.'], dtype=object)

# %%
#apolices por seguradora, Normalize = True p/ porcentagem
apolices_por_seguradora = seg['NM_RAZAO_SOCIAL'].value_counts(normalize=True, ascending=True) 
apolices_por_seguradora
# Out:
# NM_RAZAO_SOCIAL
# Companhia Excelsior de Seguros             0.00
# EZZE Seguros S.A.                          0.00
# Porto Seguro Companhia de Seguros Gerais   0.01
# Sompo Seguros S/A                          0.01
# Too Seguros S.A.                           0.02
# Aliança do Brasil Seguros S/A.             0.02
# Sancor Seguros do Brasil S.A.              0.03
# Allianz Seguros S.A                        0.04
# Swiss Re Corporate Solutions Brasil S.A.   0.05
# FairFax Brasil Seguros Corporativos S/A    0.08
# Newe Seguros S.A                           0.08
# Tokio Marine Seguradora S.A.               0.08
# Mapfre Seguros Gerais S.A.                 0.09
# Essor Seguros S.A.                         0.16
# BRASILSEG COMPANHIA DE SEGUROS             0.34
# Name: proportion, dtype: float64

# %%
apolices_por_seguradora.plot.barh()
plt.title("Apolices por seguradora (%)")
# Out:
# Text(0.5, 1.0, 'Apolices por seguradora (%)')

# %%
#LIMPEZA E ORGANIZAÇÃO DOS DADOS

# %%
#verificar se existe algum valor faltante, sem o sum retorna true e false
seg.isna().sum()
# Out:
# NM_RAZAO_SOCIAL              0
# CD_PROCESSO_SUSEP            0
# NR_PROPOSTA                  0
# ID_PROPOSTA                  0
# DT_PROPOSTA                  0
# DT_INICIO_VIGENCIA           0
# DT_FIM_VIGENCIA              0
# NM_SEGURADO                  0
# NR_DOCUMENTO_SEGURADO        0
# NM_MUNICIPIO_PROPRIEDADE     0
# SG_UF_PROPRIEDADE            0
# LATITUDE                     0
# NR_GRAU_LAT                  0
# NR_MIN_LAT                   0
# NR_SEG_LAT                   0
# LONGITUDE                    0
# NR_GRAU_LONG                 0
# NR_MIN_LONG                  0
# NR_SEG_LONG                  0
# NR_DECIMAL_LATITUDE          0
# NR_DECIMAL_LONGITUDE         0
# NM_CLASSIF_PRODUTO           0
# NM_CULTURA_GLOBAL            0
# NR_AREA_TOTAL                0
# NR_ANIMAL                    0
# NR_PRODUTIVIDADE_ESTIMADA    0
# NR_PRODUTIVIDADE_SEGURADA    0
# NivelDeCobertura             0
# VL_LIMITE_GARANTIA           0
# VL_PREMIO_LIQUIDO            0
# PE_TAXA                      0
# VL_SUBVENCAO_FEDERAL         0
# NR_APOLICE                   0
# DT_APOLICE                   0
# ANO_APOLICE                  0
# CD_GEOCMU                    0
# VALOR_INDENIZAÇÃO            0
# EVENTO_PREPONDERANTE         0
# dtype: int64

# %%
#ações possíveis para tratamento de informações faltantes (caso seja necessario)
seg = seg.fillna(0) #substitui faltantes por algum valor

# %%
#substituir faltantes de uma variável pela média da variável
seg['VL_PREMIO_LIQUIDO'] = seg['VL_PREMIO_LIQUIDO'].fillna(seg['VL_PREMIO_LIQUIDO'].mean())

# %%
#aqui temos alguns caracteres como '-', por isso vamos retirá-los no 
seg['NR_ANIMAL'].unique()
# Out:
# array([0, '-', 143, 8, 96, 141, 112, 100, 48, 1055, 176, 79, 966, 122,
#        130, 86, 90, 50, 84, 44, 25, 180, 771, 1787, 60, 53, 54, 1, 2507,
#        2, 512, 451, 110, 923, 67, 105, 24, 77, 165, 40, 69, 148, 524, 231,
#        300, 5, 3, 120, 4, 17, 6, 11, 26, 32, 13, 240, 106, 322, 94, 867,
#        125, 128, 66, 283, 37, 1323, 6200, 70, 52, 62, 80, 260, 42, 116,
#        36, 292, 10, 858, 172, 61, 43, 33, 83, 99, 57, 72, 150, 155, 216,
#        20, 273, 115, 88, 245, 64, 111, 233, 200, 183, 101, 421, 218, 163,
#        851, 55, 117, 370, 65, 196, 371, 550, 140, 169, 160, 109, 185, 268,
#        335, 426, 184, 68, 166, 535, 214, 1390, 1530, 103, 500, 87, 89,
#        235, 450, 19, 350, 30, 27, 220, 560, 145, 82, 146, 75, 45, 164, 95,
#        39, 142, 210, 76, 1300, 492, 168, 1790, 361, 212, 632, 78, 605,
#        1256, 97, 171, 34, 360, 281, 187, 41, 119, 232, 51, 74, 650, 7,
#        126, 93, 249, 279, 134, 63, 250, 285, 540, 49, 107, 1200, 14, 35,
#        38, 46, 1027, 314, 286, 22, 31, 16, 15, 312, 18, 12, 201, 9, 270,
#        508, 377, 56, 29, 157, 1006, 290, 113, 498, 1000, 242, 178, 821,
#        246, 667, 458, 720, 129, 3440, 3000, 23, 28, 3308, 85, 520, 615,
#        58, 21, 91, 71, 786, 2014, 714, 282, 710, 627, 294, 438, 203, 59,
#        179, 133, 47, 225, 295, 121, 787, 481, 832, 600, 489, 138, 269,
#        348, 124, 487], dtype=object)

# %%
#substituir caracteres como '.', '-', '...', etc
#salvando em um novo objeto, para manter os dados em seg originais
df = seg.replace(['-', '...', 'X'], 0)
df.dropna(inplace=True, how='all') #apagar ,linhas, caso ainda exista alguma com valores faltantes.

# %%
df.shape
# Out:
# (212839, 38)

# %%
df.columns
# Out:
# Index(['NM_RAZAO_SOCIAL', 'CD_PROCESSO_SUSEP', 'NR_PROPOSTA', 'ID_PROPOSTA',
#        'DT_PROPOSTA', 'DT_INICIO_VIGENCIA', 'DT_FIM_VIGENCIA', 'NM_SEGURADO',
#        'NR_DOCUMENTO_SEGURADO', 'NM_MUNICIPIO_PROPRIEDADE',
#        'SG_UF_PROPRIEDADE', 'LATITUDE', 'NR_GRAU_LAT', 'NR_MIN_LAT',
#        'NR_SEG_LAT', 'LONGITUDE', 'NR_GRAU_LONG', 'NR_MIN_LONG', 'NR_SEG_LONG',
#        'NR_DECIMAL_LATITUDE', 'NR_DECIMAL_LONGITUDE', 'NM_CLASSIF_PRODUTO',
#        'NM_CULTURA_GLOBAL', 'NR_AREA_TOTAL', 'NR_ANIMAL',
#        'NR_PRODUTIVIDADE_ESTIMADA', 'NR_PRODUTIVIDADE_SEGURADA',
#        'NivelDeCobertura', 'VL_LIMITE_GARANTIA', 'VL_PREMIO_LIQUIDO',
#        'PE_TAXA', 'VL_SUBVENCAO_FEDERAL', 'NR_APOLICE', 'DT_APOLICE',
#        'ANO_APOLICE', 'CD_GEOCMU', 'VALOR_INDENIZAÇÃO',
#        'EVENTO_PREPONDERANTE'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 212839 entries, 484614 to 697452
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   NM_RAZAO_SOCIAL            212839 non-null  object
#  1   CD_PROCESSO_SUSEP          212839 non-null  int64
#  2   NR_PROPOSTA                212839 non-null  object
#  3   ID_PROPOSTA                212839 non-null  int64
#  4   DT_PROPOSTA                212839 non-null  datetime64[ns]
#  5   DT_INICIO_VIGENCIA         212839 non-null  datetime64[ns]
#  6   DT_FIM_VIGENCIA            212839 non-null  object
#  7   NM_SEGURADO                212839 non-null  object
#  8   NR_DOCUMENTO_SEGURADO      212839 non-null  object
#  9   NM_MUNICIPIO_PROPRIEDADE   212839 non-null  object
#  10  SG_UF_PROPRIEDADE          212839 non-null  object
#  11  LATITUDE                   212839 non-null  object
#  12  NR_GRAU_LAT                212839 non-null  int64
#  13  NR_MIN_LAT                 212839 non-null  int64
#  14  NR_SEG_LAT                 212839 non-null  int64
#  15  LONGITUDE                  212839 non-null  object
#  16  NR_GRAU_LONG               212839 non-null  int64
#  17  NR_MIN_LONG                212839 non-null  int64
#  18  NR_SEG_LONG                212839 non-null  int64
#  19  NR_DECIMAL_LATITUDE        212839 non-null  object
#  20  NR_DECIMAL_LONGITUDE       212839 non-null  object
#  21  NM_CLASSIF_PRODUTO         212839 non-null  object
#  22  NM_CULTURA_GLOBAL          212839 non-null  object
#  23  NR_AREA_TOTAL              212839 non-null  float64
#  24  NR_ANIMAL                  212839 non-null  object
#  25  NR_PRODUTIVIDADE_ESTIMADA  212839 non-null  object
#  26  NR_PRODUTIVIDADE_SEGURADA  212839 non-null  object
#  27  NivelDeCobertura           212839 non-null  object
#  28  VL_LIMITE_GARANTIA         212839 non-null  float64
#  29  VL_PREMIO_LIQUIDO          212839 non-null  float64
#  30  PE_TAXA                    212839 non-null  float64
#  31  VL_SUBVENCAO_FEDERAL       212839 non-null  float64
#  32  NR_APOLICE                 212839 non-null  object
#  33  DT_APOLICE                 212839 non-null  datetime64[ns]
#  34  ANO_APOLICE                212839 non-null  int64
#  35  CD_GEOCMU                  212839 non-null  object
#  36  VALOR_INDENIZAÇÃO          212839 non-null  object
#  37  EVENTO_PREPONDERANTE       212839 non-null  object
# dtypes: datetime64[ns](3), float64(5), int64(9), object(21)
# memory usage: 63.3+ MB

# %%
#Sera criada uma nova coluna, com a duração das apolices em dias. DT_FIM_VIGENCIA, está como objeto e precisa ser alterada. 

df['DT_FIM_VIGENCIA'] = pd.to_datetime(df['DT_FIM_VIGENCIA'], errors = 'coerce')

#criar uma nova coluna com a duração das apólices
df['duracao'] = (df['DT_FIM_VIGENCIA'] - df['DT_INICIO_VIGENCIA']).dt.days

#ordenar os valores da coluna nova
df.sort_values('duracao', ascending=False)
# Out:
#                                  NM_RAZAO_SOCIAL  CD_PROCESSO_SUSEP  \
# 666334            Aliança do Brasil Seguros S/A.  15414901479201927
# 516408              Tokio Marine Seguradora S.A.  15414900116201621
# 519931              Tokio Marine Seguradora S.A.  15414900116201621
# 511450              Tokio Marine Seguradora S.A.  15414900116201621
# 509042              Tokio Marine Seguradora S.A.  15414900116201621
# ...                                          ...                ...
# 632726   FairFax Brasil Seguros Corporativos S/A  15414900270201601
# 638860   FairFax Brasil Seguros Corporativos S/A  15414900270201601
# 639227  Swiss Re Corporate Solutions Brasil S.A.  15414000338200590
# 522405   FairFax Brasil Seguros Corporativos S/A  15414900270201601
# 641300  Swiss Re Corporate Solutions Brasil S.A.  15414002154200564
#
#         NR_PROPOSTA  ID_PROPOSTA DT_PROPOSTA DT_INICIO_VIGENCIA  \
# 666334     55293108      1492577  2021-11-03         2021-11-03
# 516408      3797493      1326158  2021-03-15         2021-03-15
# 519931      3825476      1330184  2021-03-22         2021-03-22
# 511450      3777451      1320405  2021-03-09         2021-03-09
# 509042      3774079      1317629  2021-03-08         2021-03-08
# ...             ...          ...         ...                ...
# 632726         2296      1456437  2021-08-12         2021-08-12
# 638860         2436      1463098  2021-08-31         2021-08-31
# 639227  02031011564      1463493  2021-09-17         2021-09-20
# 522405         1861      1332884  2021-05-14         2021-05-14
# 641300  02011163416      1465666  2021-07-28         2021-09-01
#
#        DT_FIM_VIGENCIA                      NM_SEGURADO NR_DOCUMENTO_SEGURADO  \
# 666334      2031-11-09  MARIA HELGA HEINZ LAUBERT FILIP           ***34426915
# 516408      2026-08-16              MARILENA BORGES PAN           ***59262805
# 519931      2025-12-26        ANDRE LUIZ VALCANAIA MOSS           ***12925900
# 511450      2025-06-15      ELISANGELA PEREIRA DA SILVA           ***38092885
# 509042      2024-10-18                   EDUARD WOLBERT           ***56278919
# ...                ...                              ...                   ...
# 632726      2021-09-11       RICARDO DE ANDRADE GOUVEIA           ***34814668
# 638860      2021-09-30                   HARAS EAO LTDA        ***61008000171
# 639227      2021-10-20            Luiz Roberto Saalfeld           ***87658087
# 522405      2021-06-13    CLAUDIO SABINO CARVALHO FILHO           ***56670603
# 641300             NaT        ANTONIELE FRANCHI GALLINA           ***99205017
#
#        NM_MUNICIPIO_PROPRIEDADE SG_UF_PROPRIEDADE LATITUDE  NR_GRAU_LAT  \
# 666334               Guarapuava                PR        S           25
# 516408                    Aguai                SP        S           22
# 519931              Palmeirinha                PR        S           25
# 511450        Laranjal Paulista                SP        S           23
# 509042        Reserva do Iguaçu                PR        S           25
# ...                         ...               ...      ...          ...
# 632726             Inaciolândia                GO        S           18
# 638860                  Uberaba                MG        S           19
# 639227      São Lourenço do Sul                RS        S           31
# 522405                  Uberaba                MG        S           19
# 641300                   Aceguá                RS        S           31
#
#         NR_MIN_LAT  NR_SEG_LAT LONGITUDE  NR_GRAU_LONG  NR_MIN_LONG  \
# 666334          34          59         W            51           32
# 516408           8           3         W            46           56
# 519931          16          49         W            51           39
# 511450           1          31         W            47           52
# 509042          50           1         W            52            2
# ...            ...         ...       ...           ...          ...
# 632726          25          10         W            50            0
# 638860          50          26         W            48            3
# 639227          24          15         W            52            0
# 522405          37           0         W            47           59
# 641300          44          37         W            54            8
#
#         NR_SEG_LONG NR_DECIMAL_LATITUDE NR_DECIMAL_LONGITUDE  \
# 666334           34                   0                    0
# 516408           48                   0                    0
# 519931           42                   0                    0
# 511450           23                   0                    0
# 509042           35                   0                    0
# ...             ...                 ...                  ...
# 632726            8                   0                    0
# 638860           24                   0                    0
# 639227           51                   0                    0
# 522405           26                   0                    0
# 641300           15                   0                    0
#
#        NM_CLASSIF_PRODUTO NM_CULTURA_GLOBAL  NR_AREA_TOTAL NR_ANIMAL  \
# 666334            CUSTEIO              Soja          21.13         0
# 516408            CUSTEIO            Tomate          30.00         0
# 519931            CUSTEIO            Batata         100.00         0
# 511450            CUSTEIO            Tomate           8.00         0
# 509042            CUSTEIO            Batata         100.00         0
# ...                   ...               ...            ...       ...
# 632726      PRODUTIVIDADE          Pecuário           0.00         7
# 638860      PRODUTIVIDADE          Pecuário           0.00        47
# 639227           PECUÁRIO          Pecuário           0.00         1
# 522405      PRODUTIVIDADE          Pecuário           0.00         6
# 641300      PRODUTIVIDADE              Soja         152.00         0
#
#        NR_PRODUTIVIDADE_ESTIMADA NR_PRODUTIVIDADE_SEGURADA NivelDeCobertura  \
# 666334                   4199.60                   3359.68             0.80
# 516408                         0                         0                0
# 519931                         0                         0                0
# 511450                         0                         0                0
# 509042                         0                         0                0
# ...                          ...                       ...              ...
# 632726                         0                         0                0
# 638860                         0                         0                0
# 639227                         0                         0                0
# 522405                         0                         0                0
# 641300                      2329                      1514             0.65
#
#         VL_LIMITE_GARANTIA  VL_PREMIO_LIQUIDO  PE_TAXA  VL_SUBVENCAO_FEDERAL  \
# 666334            82407.00            2820.15     0.03                564.03
# 516408           846749.99           44827.00     0.05              17930.80
# 519931          1296000.00           89424.00     0.07              35769.60
# 511450           117120.00           16683.00     0.14               6673.20
# 509042          1600000.00          110399.00     0.07              44159.60
# ...                    ...                ...      ...                   ...
# 632726           253500.00            3422.25     0.01               1368.90
# 638860          1848200.00           24950.69     0.01               9980.28
# 639227           240000.00            1440.00     0.01                575.99
# 522405           241500.00            3260.25     0.01               1304.10
# 641300           575472.00           49634.48     0.09               9926.89
#
#            NR_APOLICE DT_APOLICE  ANO_APOLICE CD_GEOCMU VALOR_INDENIZAÇÃO  \
# 666334          23732 2021-11-09         2021   4109401                 0
# 516408       10268884 2021-03-18         2021         0                 0
# 519931        1050235 2021-04-06         2021   4109401          83342.56
# 511450       10268849 2021-03-17         2021   3526407                 0
# 509042        1050223 2021-03-22         2021   4121752                 0
# ...               ...        ...          ...       ...               ...
# 632726  1000300001668 2021-08-12         2021   5209937                 0
# 638860  1000300001745 2021-09-17         2021   3170107                 0
# 639227    02030004429 2021-09-28         2021   4318804                 0
# 522405  1000300001365 2021-05-24         2021   3170107                 0
# 641300    02010111324 2021-10-05         2021   4300034                 0
#
#        EVENTO_PREPONDERANTE  duracao
# 666334                    0  3658.00
# 516408                    0  1980.00
# 519931                GEADA  1740.00
# 511450                    0  1559.00
# 509042                    0  1320.00
# ...                     ...      ...
# 632726                    0    30.00
# 638860                    0    30.00
# 639227                    0    30.00
# 522405                    0    30.00
# 641300                    0      NaN
#
# [212839 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 212839 entries, 484614 to 697452
# Data columns (total 39 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   NM_RAZAO_SOCIAL            212839 non-null  object
#  1   CD_PROCESSO_SUSEP          212839 non-null  int64
#  2   NR_PROPOSTA                212839 non-null  object
#  3   ID_PROPOSTA                212839 non-null  int64
#  4   DT_PROPOSTA                212839 non-null  datetime64[ns]
#  5   DT_INICIO_VIGENCIA         212839 non-null  datetime64[ns]
#  6   DT_FIM_VIGENCIA            212838 non-null  datetime64[ns]
#  7   NM_SEGURADO                212839 non-null  object
#  8   NR_DOCUMENTO_SEGURADO      212839 non-null  object
#  9   NM_MUNICIPIO_PROPRIEDADE   212839 non-null  object
#  10  SG_UF_PROPRIEDADE          212839 non-null  object
#  11  LATITUDE                   212839 non-null  object
#  12  NR_GRAU_LAT                212839 non-null  int64
#  13  NR_MIN_LAT                 212839 non-null  int64
#  14  NR_SEG_LAT                 212839 non-null  int64
#  15  LONGITUDE                  212839 non-null  object
#  16  NR_GRAU_LONG               212839 non-null  int64
#  17  NR_MIN_LONG                212839 non-null  int64
#  18  NR_SEG_LONG                212839 non-null  int64
#  19  NR_DECIMAL_LATITUDE        212839 non-null  object
#  20  NR_DECIMAL_LONGITUDE       212839 non-null  object
#  21  NM_CLASSIF_PRODUTO         212839 non-null  object
#  22  NM_CULTURA_GLOBAL          212839 non-null  object
#  23  NR_AREA_TOTAL              212839 non-null  float64
#  24  NR_ANIMAL                  212839 non-null  object
#  25  NR_PRODUTIVIDADE_ESTIMADA  212839 non-null  object
#  26  NR_PRODUTIVIDADE_SEGURADA  212839 non-null  object
#  27  NivelDeCobertura           212839 non-null  object
#  28  VL_LIMITE_GARANTIA         212839 non-null  float64
#  29  VL_PREMIO_LIQUIDO          212839 non-null  float64
#  30  PE_TAXA                    212839 non-null  float64
#  31  VL_SUBVENCAO_FEDERAL       212839 non-null  float64
#  32  NR_APOLICE                 212839 non-null  object
#  33  DT_APOLICE                 212839 non-null  datetime64[ns]
#  34  ANO_APOLICE                212839 non-null  int64
#  35  CD_GEOCMU                  212839 non-null  object
#  36  VALOR_INDENIZAÇÃO          212839 non-null  object
#  37  EVENTO_PREPONDERANTE       212839 non-null  object
#  38  duracao                    212838 non-null  float64
# dtypes: datetime64[ns](4), float64(6), int64(9), object(20)
# memory usage: 65.0+ MB

# %%
#algumas colunas serão retiradas
retirar = ['CD_PROCESSO_SUSEP', 'NR_PROPOSTA', 'ID_PROPOSTA', 'DT_PROPOSTA', 'DT_INICIO_VIGENCIA', 
           'DT_FIM_VIGENCIA', 'NM_SEGURADO', 'NR_DOCUMENTO_SEGURADO', 'LATITUDE', 'NR_GRAU_LAT', 'NR_MIN_LAT', 
          'NR_SEG_LAT', 'LONGITUDE', 'NR_GRAU_LONG', 'NR_MIN_LONG', 'NR_SEG_LONG', 'NR_DECIMAL_LATITUDE', 
           'NR_DECIMAL_LONGITUDE', 'DT_APOLICE', 'ANO_APOLICE']
df = df.drop(retirar, axis = 1)

# %%
#necessario retirar os catacteres a mais
df['EVENTO_PREPONDERANTE'].unique()
# Out:
# array(['\xa0SECA', 0, '\xa0GEADA', '\xa0GRANIZO',
#        '\xa0VENTOS FORTES/FRIOS', '\xa0CHUVA EXCESSIVA', '\xa0INCÊNDIO',
#        '\xa0DEMAIS CAUSAS', '\xa0VARIAÇÃO EXCESSIVA DE TEMPERATURA',
#        '\xa0RAIO', '\xa0MORTE', '\xa0INUNDAÇÃO/TROMBA D´ÁGUA',
#        '\xa0VARIAÇÃO DE PREÇO', '\xa0DOENÇAS E PRAGAS',
#        '\xa0QUEDA DE PARREIRAL', '\xa0PERDA DE QUALIDADE',
#        '\xa0REPLANTIO'], dtype=object)

# %%
df['EVENTO_PREPONDERANTE'] = df['EVENTO_PREPONDERANTE'].str.split().str.join('  ') #separa as strings e junta elas apenas onde ficaram com 2 espaços
df['EVENTO_PREPONDERANTE'] = df['EVENTO_PREPONDERANTE'].replace([np.nan], '0') #OBS: existem vários tipos de

# %%
df['EVENTO_PREPONDERANTE'].unique()
# Out:
# array(['SECA', '0', 'GEADA', 'GRANIZO', 'VENTOS  FORTES/FRIOS',
#        'CHUVA  EXCESSIVA', 'INCÊNDIO', 'DEMAIS  CAUSAS',
#        'VARIAÇÃO  EXCESSIVA  DE  TEMPERATURA', 'RAIO', 'MORTE',
#        'INUNDAÇÃO/TROMBA  D´ÁGUA', 'VARIAÇÃO  DE  PREÇO',
#        'DOENÇAS  E  PRAGAS', 'QUEDA  DE  PARREIRAL',
#        'PERDA  DE  QUALIDADE', 'REPLANTIO'], dtype=object)

# %%
df.shape
# Out:
# (212839, 19)

# %%
#retirar espaços em branco (caso haja algum)
df['NM_RAZAO_SOCIAL'] = df['NM_RAZAO_SOCIAL'].str.strip()
df['NM_CULTURA_GLOBAL'] = df['NM_CULTURA_GLOBAL'].str.strip()

# %%
#USO DO GROUPBY
df.groupby('SG_UF_PROPRIEDADE')['VL_PREMIO_LIQUIDO'].sum().sort_values(ascending=False) #agrupando a soma dos prêmios líquidos por Estado
# Out:
# SG_UF_PROPRIEDADE
# PR   1207568809.67
# RS    943467577.41
# MS    416927473.24
# SP    387538424.06
# GO    341964503.67
# MG    213468609.40
# MT    167714176.38
# SC    164561358.71
# BA     70505887.60
# TO     70003349.94
# MA     59008550.89
# PI     30612102.75
# SE     15288463.45
# ES     14315532.89
# PA     12281555.47
# RO      5619605.37
# DF      2778740.08
# AM      1506708.51
# PB      1272811.28
# AL      1116403.03
# PE       333569.43
# AC       231113.51
# RJ       211341.99
# RR       138730.63
# CE        30761.83
# RN         4388.67
# Name: VL_PREMIO_LIQUIDO, dtype: float64

# %%
premio_estado =  df.groupby('SG_UF_PROPRIEDADE')['VL_PREMIO_LIQUIDO'].sum().sort_values(ascending=True)
premio_estado.plot.barh()
plt.title("Valores segurados por Estado (Bilhões)")
# Out:
# Text(0.5, 1.0, 'Valores segurados por Estado (Bilhões)')

# %%
#CALCULANDO O ÍNDICE DE SINISTRALIDADE
#O índice mede (em %) a participação do valor total de indenizações pagas aos produtores,
#em relação ao valor total do prêmio arrecadado pelas seguradoras. 65% é entendido como valor limite aceitável. 
#Esse índice permite inferencias sobre o equilíbrio atuarial das operações de seguro rural. 

sinistralidade = (df['VALOR_INDENIZAÇÃO'].sum()) / (df['VL_PREMIO_LIQUIDO'].sum()) * 100 
print("Índice de Sinistralidade" + " é " + str(sinistralidade) + " %")
# Out:
# Índice de Sinistralidade é 236.92896963035457 %

# %%
#alterando o nome das colunas, lembrando que todas precisam estar na ordem que aparecem no dataframe
df.columns = ['seguradora', 'municipio', 'uf', 'tipo_prod', 'cultura', 
             'area', 'animal', 'prod_est', 'prod_seg', 'nivel_cob', 'total_seg', 'premio',
             'taxa', 'subvencao', 'apolice', 'cod_mun', 'indenizacao', 'evento', 'duracao']

# %%
#novos nomes; Dtype ok
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 212839 entries, 484614 to 697452
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   seguradora   212839 non-null  object
#  1   municipio    212839 non-null  object
#  2   uf           212839 non-null  object
#  3   tipo_prod    212839 non-null  object
#  4   cultura      212839 non-null  object
#  5   area         212839 non-null  float64
#  6   animal       212839 non-null  object
#  7   prod_est     212839 non-null  object
#  8   prod_seg     212839 non-null  object
#  9   nivel_cob    212839 non-null  object
#  10  total_seg    212839 non-null  float64
#  11  premio       212839 non-null  float64
#  12  taxa         212839 non-null  float64
#  13  subvencao    212839 non-null  float64
#  14  apolice      212839 non-null  object
#  15  cod_mun      212839 non-null  object
#  16  indenizacao  212839 non-null  object
#  17  evento       212839 non-null  object
#  18  duracao      212838 non-null  float64
# dtypes: float64(6), object(13)
# memory usage: 32.5+ MB

# %%
#transformando mun em inteiro, pois é um código
df['cod_mun'] = df['cod_mun'].astype(int)
df['indenizacao'] = df['indenizacao'].astype(float)

# %%
#criando uma coluna com a sinistralidade
df['sinistralidade'] = df['indenizacao'] / df['premio']
df.sample(10)
# Out:
#                                       seguradora          municipio  uf  \
# 663522              Tokio Marine Seguradora S.A.     Esperança Nova  PR
# 572399            BRASILSEG COMPANHIA DE SEGUROS           Espumoso  RS
# 632345            BRASILSEG COMPANHIA DE SEGUROS         Ponta Porã  MS
# 669752            Aliança do Brasil Seguros S/A.        Curral Alto  RS
# 519718                        Essor Seguros S.A.           Angelina  SC
# 657099  Swiss Re Corporate Solutions Brasil S.A.  Centenário do Sul  PR
# 637833            BRASILSEG COMPANHIA DE SEGUROS      Prudentópolis  PR
# 625758   FairFax Brasil Seguros Corporativos S/A       Santo Inácio  PR
# 647979  Swiss Re Corporate Solutions Brasil S.A.     Paulo de Faria  SP
# 652509                Mapfre Seguros Gerais S.A.            Itaberá  SP
#
#             tipo_prod         cultura   area animal prod_est prod_seg  \
# 663522  PRODUTIVIDADE  Milho 1ª safra  32.30      0     3500     2450
# 572399        CUSTEIO            Soja 155.00      0     3000     1950
# 632345        CUSTEIO            Soja  32.90      0     3600     2520
# 669752        CUSTEIO            Soja  23.00      0     2912  1892.80
# 519718  PRODUTIVIDADE             Uva   0.73      0    25000    25000
# 657099  PRODUTIVIDADE            Soja  21.03      0     2622     1835
# 637833        CUSTEIO            Soja  18.15      0     3391  2373.70
# 625758  PRODUTIVIDADE            Soja  72.95      0  2806.80  1824.60
# 647979  PRODUTIVIDADE            Soja  28.00      0     2850     1996
# 652509  PRODUTIVIDADE            Soja  12.93      0     4680     3276
#
#        nivel_cob  total_seg   premio  taxa  subvencao        apolice  cod_mun  \
# 663522      0.70  118702.50  8161.00  0.07    2040.25       10282466  4107520
# 572399      0.65  550544.50 50207.26  0.09   10041.45         136797  4307500
# 632345      0.70   82566.83  6854.84  0.08    1370.97         147436  5006606
# 669752      0.65   80500.01  6797.76  0.08    1359.55          22852  4317301
# 519718         1   18250.00  2418.13  0.13     967.25  1000111143071  4200903
# 657099      0.70   96496.16  8496.92  0.09    1699.37    02010112214  4105102
# 637833      0.70   79064.72  4219.64  0.05    2531.78         162929  4120606
# 625758      0.65  354945.52 33080.92  0.09    6616.18  1000100053913  4124509
# 647979      0.70  139692.00 10365.15  0.07    2073.02    02010111012  3536604
# 652509      0.70   77657.58  3997.80  0.05     799.56  6061000478501  3521705
#
#         indenizacao            evento  duracao  sinistralidade
# 663522         0.00                 0   193.00            0.00
# 572399    107480.49              SECA   365.00            2.14
# 632345         0.00              SECA   365.00            0.00
# 669752         0.00              SECA   365.00            0.00
# 519718         0.00           GRANIZO   333.00            0.00
# 657099         0.00                 0   244.00            0.00
# 637833     33369.81              SECA   365.00            7.91
# 625758    266238.32              SECA   237.00            8.05
# 647979     34540.02  CHUVA  EXCESSIVA   273.00            3.33
# 652509         0.00           GRANIZO   183.00            0.00

# %%
#variável de indicação: 0 = não houve sinistro; 1 = houve sinistro a partir da variável evento
#caso 'evento' seja 0 = não houve sisnitro; se 'evento' = SECA, CHUVA EXCESSIVA, etc., existiu sinistro
df['sinistro'] = np.where(df['evento'].str.isnumeric(), 0, 1)

# %%
df.describe()
# Out:
#            area    total_seg    premio      taxa  subvencao    cod_mun  \
# count 212839.00    212839.00 212839.00 212839.00  212839.00  212839.00
# mean      64.30    312463.30  19397.15      0.08    5416.18 3992490.81
# std      672.28   1374670.95  27293.34      0.04    6703.20  843198.82
# min        0.00       753.48     55.34      0.00       0.01       0.00
# 25%       12.42     71916.99   4960.00      0.05    1499.85 4101150.00
# 50%       30.00    150027.47  10239.68      0.07    3147.74 4117909.00
# 75%       71.80    338111.80  22598.85      0.10    6540.79 4307401.00
# max   290985.00 520323520.32 893218.14      1.00   48000.00 5300108.00
#
#        indenizacao   duracao  sinistralidade  sinistro
# count    212839.00 212838.00       212839.00 212839.00
# mean      45957.47    296.29            2.55      0.52
# std      125667.89     77.16            4.25      0.50
# min           0.00     30.00            0.00      0.00
# 25%           0.00    227.00            0.00      0.00
# 50%           0.00    321.00            0.00      1.00
# 75%       40372.90    365.00            4.49      1.00
# max     6407193.25   3658.00          203.98      1.00

# %%
df.columns
# Out:
# Index(['seguradora', 'municipio', 'uf', 'tipo_prod', 'cultura', 'area',
#        'animal', 'prod_est', 'prod_seg', 'nivel_cob', 'total_seg', 'premio',
#        'taxa', 'subvencao', 'apolice', 'cod_mun', 'indenizacao', 'evento',
#        'duracao', 'sinistralidade', 'sinistro'],
#       dtype='object')

# %%
#Reorganizando as variáveis para melhor visualização usando .loc
df = df.loc[:, ['apolice', 'cod_mun', 'municipio', 'uf', 'tipo_prod','seguradora', 'cultura', 'area', 'animal', 
                'duracao', 'prod_est', 'prod_seg', 'total_seg', 'premio', 'taxa', 'subvencao',
               'indenizacao', 'evento', 'sinistro', 'sinistralidade']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 212839 entries, 484614 to 697452
# Data columns (total 20 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   apolice         212839 non-null  object
#  1   cod_mun         212839 non-null  int64
#  2   municipio       212839 non-null  object
#  3   uf              212839 non-null  object
#  4   tipo_prod       212839 non-null  object
#  5   seguradora      212839 non-null  object
#  6   cultura         212839 non-null  object
#  7   area            212839 non-null  float64
#  8   animal          212839 non-null  object
#  9   duracao         212838 non-null  float64
#  10  prod_est        212839 non-null  object
#  11  prod_seg        212839 non-null  object
#  12  total_seg       212839 non-null  float64
#  13  premio          212839 non-null  float64
#  14  taxa            212839 non-null  float64
#  15  subvencao       212839 non-null  float64
#  16  indenizacao     212839 non-null  float64
#  17  evento          212839 non-null  object
#  18  sinistro        212839 non-null  int64
#  19  sinistralidade  212839 non-null  float64
# dtypes: float64(8), int64(2), object(10)
# memory usage: 34.1+ MB

# %%
#ascending = True, mostra do menor para o maior.
df.sort_values('premio')
# Out:
#               apolice  cod_mun  municipio  uf      tipo_prod  \
# 657878  1000100057010  3149101   Pedralva  MG  PRODUTIVIDADE
# 686715         152660  3139409   Manhuaçu  MG        CUSTEIO
# 620041  1000111091873  3128105      Guapé  MG  PRODUTIVIDADE
# 654885  1000100056630  3125200       Fama  MG  PRODUTIVIDADE
# 489399  6609001933201  3144003      Mutum  MG        CUSTEIO
# ...               ...      ...        ...  ..            ...
# 686277         190769  2201903  Bom Jesus  PI        CUSTEIO
# 686042         159808  2106706    Mirador  MA        CUSTEIO
# 685843         145974  4205902     Gaspar  SC        CUSTEIO
# 593257  1000111164599  4322509    Vacaria  RS  PRODUTIVIDADE
# 689350         189773  1709302     Guaraí  TO        CUSTEIO
#
#                                      seguradora         cultura    area  \
# 657878  FairFax Brasil Seguros Corporativos S/A            Café    0.60
# 686715           BRASILSEG COMPANHIA DE SEGUROS            Café    0.10
# 620041            Sancor Seguros do Brasil S.A.            Café    0.28
# 654885  FairFax Brasil Seguros Corporativos S/A            Café    0.38
# 489399               Mapfre Seguros Gerais S.A.            Café    1.00
# ...                                         ...             ...     ...
# 686277           BRASILSEG COMPANHIA DE SEGUROS  Milho 1ª safra 1280.00
# 686042           BRASILSEG COMPANHIA DE SEGUROS            Soja 2256.60
# 685843           BRASILSEG COMPANHIA DE SEGUROS            Soja 1560.00
# 593257                       Essor Seguros S.A.            Maçã  167.55
# 689350           BRASILSEG COMPANHIA DE SEGUROS            Soja 1253.49
#
#        animal  duracao prod_est prod_seg   total_seg    premio  taxa  \
# 657878      0   303.00        0        0     8100.00     55.34  0.01
# 686715      0   365.00     3250     2275     1522.89     66.38  0.04
# 620041      0   366.00        0        0     1680.00     71.40  0.04
# 654885      0   320.00        0        0     6498.00     99.95  0.02
# 489399      0   365.00        0        0     7000.00    100.00  0.01
# ...       ...      ...      ...      ...         ...       ...   ...
# 686277      0   365.00     5909  3840.85  6572800.02 645849.04  0.10
# 686042      0   365.00     3000     1950  8384900.02 655741.07  0.08
# 685843      0   365.00     2273  1477.45 14872802.41 761325.53  0.05
# 593257      0   319.00    48542    48542  7556670.00 803274.07  0.11
# 689350      0   365.00     3000     1950  8035627.71 893218.14  0.11
#
#         subvencao  indenizacao   evento  sinistro  sinistralidade
# 657878      22.14         0.00        0         0            0.00
# 686715      26.55         0.00        0         0            0.00
# 620041      28.56         0.00        0         0            0.00
# 654885      39.98         0.00        0         0            0.00
# 489399      40.00         0.00        0         0            0.00
# ...           ...          ...      ...       ...             ...
# 686277    6456.67         0.00        0         0            0.00
# 686042   48000.00         0.00        0         0            0.00
# 685843   10394.00         0.00        0         0            0.00
# 593257   48000.00    143111.85  GRANIZO         1            0.18
# 689350   22095.96         0.00        0         0            0.00
#
# [212839 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['apolice', 'cod_mun', 'municipio', 'uf', 'tipo_prod', 'seguradora',
#        'cultura', 'area', 'animal', 'duracao', 'prod_est', 'prod_seg',
#        'total_seg', 'premio', 'taxa', 'subvencao', 'indenizacao', 'evento',
#        'sinistro', 'sinistralidade'],
#       dtype='object')

# %%
#selecionando algumas colunas e o valor de subvenção
df[['municipio', 'uf', 'cultura', 'subvencao']].sort_values('subvencao', ascending=False)
# Out:
#             municipio  uf         cultura  subvencao
# 490899        Itaberá  SP           Sorgo   48000.00
# 542219  Campos Gerais  MG            Café   48000.00
# 697437         Guaraí  TO  Milho 2ª safra   48000.00
# 532082   Aral Moreira  MS  Milho 2ª safra   48000.00
# 696465         Balsas  MA  Milho 2ª safra   48000.00
# ...               ...  ..             ...        ...
# 606330  Muitos Capões  RS            Maçã       0.01
# 646569        Amambaí  MS            Soja       0.01
# 531433        Vacaria  RS            Maçã       0.01
# 532169        Mamborê  PR           Trigo       0.01
# 611206   Campo Mourão  PR           Trigo       0.01
#
# [212839 rows x 4 columns]

# %%
df.shape #mesmo número de linhas da base SEG
# Out:
# (212839, 20)

# %%
#Salvando os dados limpos como xlsx (index = false para não salvar o df como uma coluna do df atual)
df.to_excel("seguro-rural-limpo-2016-2021.xlsx", index = False)

# %%
#caso quisermos salvar como csv
#df.to_excel("seguro-rural-2021.csv", index=False, encoding='latin1')

# %%
#verificar se os dados serão lidos corretamente
#com os dados limpos, vamos fazer a análise Exploratória
df = pd.read_excel("seguro-rural-limpo-2016-2021.xlsx")

# %%
df.head()
# Out:
#           apolice  cod_mun                  municipio  uf      tipo_prod  \
# 0  10001010026768  5218805                  Rio Verde  GO        CUSTEIO
# 1          494404  5211909                      Jataí  GO        CUSTEIO
# 2   4525000065701  5107859      São Félix do Araguaia  MT  PRODUTIVIDADE
# 3   1000100040113  4107306             Doutor Camargo  PR  PRODUTIVIDADE
# 4   1000111016260  4126009  São Sebastião da Amoreira  PR  PRODUTIVIDADE
#
#                                 seguradora         cultura   area  animal  \
# 0                         Newe Seguros S.A  Milho 2ª safra  62.00       0
# 1           BRASILSEG COMPANHIA DE SEGUROS  Milho 2ª safra 268.00       0
# 2               Mapfre Seguros Gerais S.A.  Milho 2ª safra 850.00       0
# 3  FairFax Brasil Seguros Corporativos S/A  Milho 2ª safra  15.73       0
# 4                         Too Seguros S.A.  Milho 2ª safra 124.97       0
#
#    duracao  prod_est  prod_seg  total_seg    premio  taxa  subvencao  \
# 0   181.00   6171.60   4011.60  133064.77   7895.27  0.06    3158.11
# 1   365.00   6013.00   3908.45  608223.32  33452.28  0.05   13380.91
# 2   244.00   6276.00   4079.40 2311660.00 195224.61  0.08   48000.00
# 3   278.00   5569.80   3620.40   47457.41   5277.26  0.11    2110.90
# 4   180.00   5226.00   3658.20  304776.84  43755.91  0.14   17502.36
#
#    indenizacao evento  sinistro  sinistralidade
# 0     17583.39   SECA         1            2.23
# 1         0.00      0         0            0.00
# 2         0.00      0         0            0.00
# 3     16413.80   SECA         1            3.11
# 4    248902.36   SECA         1            5.69

# %%
df.describe()
# Out:
#          cod_mun      area    animal   duracao    prod_est    prod_seg  \
# count  212839.00 212839.00 212839.00 212838.00   212839.00   212839.00
# mean  3992490.81     64.30      0.57    296.29    12965.90    11758.34
# std    843198.82    672.28     25.32     77.16   471610.19   471605.02
# min         0.00      0.00      0.00     30.00        0.00        0.00
# 25%   4101150.00     12.42      0.00    227.00     3000.00     2047.50
# 50%   4117909.00     30.00      0.00    321.00     3651.60     2542.00
# 75%   4307401.00     71.80      0.00    365.00     5500.00     3720.60
# max   5300108.00 290985.00   6200.00   3658.00 80000000.00 80000000.00
#
#          total_seg    premio      taxa  subvencao  indenizacao  sinistro  \
# count    212839.00 212839.00 212839.00  212839.00    212839.00 212839.00
# mean     312463.30  19397.15      0.08    5416.18     45957.47      0.52
# std     1374670.95  27293.34      0.04    6703.20    125667.89      0.50
# min         753.48     55.34      0.00       0.01         0.00      0.00
# 25%       71916.99   4960.00      0.05    1499.85         0.00      0.00
# 50%      150027.47  10239.68      0.07    3147.74         0.00      1.00
# 75%      338111.80  22598.85      0.10    6540.79     40372.90      1.00
# max   520323520.32 893218.14      1.00   48000.00   6407193.25      1.00
#
#        sinistralidade
# count       212839.00
# mean             2.55
# std              4.25
# min              0.00
# 25%              0.00
# 50%              0.00
# 75%              4.49
# max            203.98

# %%
df.dtypes
# Out:
# apolice            object
# cod_mun             int64
# municipio          object
# uf                 object
# tipo_prod          object
# seguradora         object
# cultura            object
# area              float64
# animal              int64
# duracao           float64
# prod_est          float64
# prod_seg          float64
# total_seg         float64
# premio            float64
# taxa              float64
# subvencao         float64
# indenizacao       float64
# evento             object
# sinistro            int64
# sinistralidade    float64
# dtype: object

# %%
df.shape
# Out:
# (212839, 20)

# %%
#resumo estatístico apenas de algumas variáveis, seleção usando iloc (números das linhas e colunas)
df.iloc[:, 5:].describe()
# Out:
#            area    animal   duracao    prod_est    prod_seg    total_seg  \
# count 212839.00 212839.00 212838.00   212839.00   212839.00    212839.00
# mean      64.30      0.57    296.29    12965.90    11758.34    312463.30
# std      672.28     25.32     77.16   471610.19   471605.02   1374670.95
# min        0.00      0.00     30.00        0.00        0.00       753.48
# 25%       12.42      0.00    227.00     3000.00     2047.50     71916.99
# 50%       30.00      0.00    321.00     3651.60     2542.00    150027.47
# 75%       71.80      0.00    365.00     5500.00     3720.60    338111.80
# max   290985.00   6200.00   3658.00 80000000.00 80000000.00 520323520.32
#
#          premio      taxa  subvencao  indenizacao  sinistro  sinistralidade
# count 212839.00 212839.00  212839.00    212839.00 212839.00       212839.00
# mean   19397.15      0.08    5416.18     45957.47      0.52            2.55
# std    27293.34      0.04    6703.20    125667.89      0.50            4.25
# min       55.34      0.00       0.01         0.00      0.00            0.00
# 25%     4960.00      0.05    1499.85         0.00      0.00            0.00
# 50%    10239.68      0.07    3147.74         0.00      1.00            0.00
# 75%    22598.85      0.10    6540.79     40372.90      1.00            4.49
# max   893218.14      1.00   48000.00   6407193.25      1.00          203.98

# %%
#Existem dados duplicados? 
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [apolice, cod_mun, municipio, uf, tipo_prod, seguradora, cultura, area, animal, duracao, prod_est, prod_seg, total_seg, premio, taxa, subvencao, indenizacao, evento, sinistro, sinistralidade]
# Index: []

# %%
#podemos usar para um subconjunto dos dados
df.loc[df.duplicated(subset=['apolice'])]
# Out:
# Empty DataFrame
# Columns: [apolice, cod_mun, municipio, uf, tipo_prod, seguradora, cultura, area, animal, duracao, prod_est, prod_seg, total_seg, premio, taxa, subvencao, indenizacao, evento, sinistro, sinistralidade]
# Index: []

# %%
#verificar dados únicos para todo o conjunto de dados
df.nunique()
# Out:
# apolice           212839
# cod_mun             2938
# municipio           3859
# uf                    26
# tipo_prod              4
# seguradora            15
# cultura               64
# area               18974
# animal               256
# duracao              528
# prod_est           15958
# prod_seg           19297
# total_seg         174034
# premio            187388
# taxa              185101
# subvencao         175983
# indenizacao        82208
# evento                17
# sinistro               2
# sinistralidade     82681
# dtype: int64

# %%
#ocorrencias unicas de evento
df['evento'].unique()
# Out:
# array(['SECA', '0', 'GEADA', 'GRANIZO', 'VENTOS  FORTES/FRIOS',
#        'CHUVA  EXCESSIVA', 'INCÊNDIO', 'DEMAIS  CAUSAS',
#        'VARIAÇÃO  EXCESSIVA  DE  TEMPERATURA', 'RAIO', 'MORTE',
#        'INUNDAÇÃO/TROMBA  D´ÁGUA', 'VARIAÇÃO  DE  PREÇO',
#        'DOENÇAS  E  PRAGAS', 'QUEDA  DE  PARREIRAL',
#        'PERDA  DE  QUALIDADE', 'REPLANTIO'], dtype=object)

# %%
#trocando os nomes das ocorrencias de evento para melhorar a plotagem
#o argumento da função é um dicionário
df['evento'].replace({'0' : 'nenhum',
                      'SECA' : 'seca', 
                      'GEADA': 'geada',
                      'GRANIZO': 'granizo',
                      'VENTOS  FORTES/FRIOS': 'ventos',
                      'CHUVA  EXCESSIVA': 'chuva',
                      'INCÊNDIO': 'incendio',
                      'DEMAIS  CAUSAS': 'demais causas',
                      'VARIAÇÃO  EXCESSIVA  DE  TEMPERATURA': 'temperatura',
                      'RAIO': 'raio',
                      'MORTE': 'morte',
                      'INUNDAÇÃO/TROMBA  D´ÁGUA': 'inundacao',
                      'VARIAÇÃO  DE  PREÇO': 'var. preco',
                      'DOENÇAS  E  PRAGAS': 'doenças',
                      'QUEDA  DE  PARREIRAL': 'queda parreiral',
                      'PERDA  DE  QUALIDADE': 'perda qualidade',
                      'REPLANTIO': 'replantio'}, inplace=True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_16768\3188469110.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['evento'].replace({'0' : 'nenhum',

# %%
#ocorrencias unicas de evento
df['evento'].unique()
# Out:
# array(['seca', 'nenhum', 'geada', 'granizo', 'ventos', 'chuva',
#        'incendio', 'demais causas', 'temperatura', 'raio', 'morte',
#        'inundacao', 'var. preco', 'doenças', 'queda parreiral',
#        'perda qualidade', 'replantio'], dtype=object)

# %%
df['tipo_prod'].unique()
# Out:
# array(['CUSTEIO', 'PRODUTIVIDADE', 'PECUÁRIO', 'FLORESTAS'], dtype=object)

# %%
#trocar de maíusculas pra minúsculas
df['tipo_prod'].replace({ 'CUSTEIO': 'custeio',
                          'PRODUTIVIDADE': 'produtividade',
                          'PECUÁRIO': 'pecuario',
                          'FLORESTAS': 'florestas'}, inplace=True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_16768\3784311105.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['tipo_prod'].replace({ 'CUSTEIO': 'custeio',

# %%
#algumas consultas, por exemplo, quais foram as apolices de uva? 
#verificando as culturas 
df['cultura'].unique()
# Out:
# array(['Milho 2ª safra', 'Uva', 'Tomate', 'Feijão 1ª safra', 'Sorgo',
#        'Café', 'Trigo', 'Feijão 2ª safra', 'Milho 1ª safra', 'Repolho',
#        'Tangerina', 'Atemoia', 'Pecuário', 'Floresta', 'Pepino',
#        'Cana-de-açúcar', 'Pimentão', 'Soja', 'Abobrinha', 'Alho',
#        'Berinjela', 'Beterraba', 'Canola', 'Melancia', 'Abóbora',
#        'Batata', 'Aveia', 'Cebola', 'Abacate', 'Couve-flor', 'Laranja',
#        'Triticale', 'Cenoura', 'Goiaba', 'Cevada', 'Banana', 'Ervilha',
#        'Pêssego', 'Ameixa', 'Amendoim', 'Mandioca', 'Maracujá',
#        'Brócolis', 'Alface', 'Caqui', 'Nectarina', 'Mamão', 'Kiwi',
#        'Vagem', 'Maçã', 'Arroz', 'Abacaxi', 'Lichia', 'Manga', 'Morango',
#        'Chuchu', 'Pêra', 'Limão', 'Algodão', 'Girassol', 'Figo', 'Cacau',
#        'Melão', 'Pastagem'], dtype=object)

# %%
#apolices de uva 
df[df['cultura'] == 'Uva']
# Out:
#               apolice  cod_mun   municipio  uf      tipo_prod  \
# 13      1000111138664  3556701     Vinhedo  SP  produtividade
# 21      1000111138665  3527306    Louveira  SP  produtividade
# 30      1000111138666  3527306    Louveira  SP  produtividade
# 38      1000111138667  3556701     Vinhedo  SP  produtividade
# 46      1000111138668  3556701     Vinhedo  SP  produtividade
# ...               ...      ...         ...  ..            ...
# 183779       10282750  4301800    Barracão  RS        custeio
# 195353       10283031  3152907  Pratápolis  MG        custeio
# 195857       10283033  3152907  Pratápolis  MG        custeio
# 200120       10461327  2611101   Petrolina  PE        custeio
# 205033  2444000010401        0    Juazeiro  BA        custeio
#
#                           seguradora cultura  area  animal  duracao  prod_est  \
# 13                Essor Seguros S.A.     Uva 10.12       0   192.00  11429.00
# 21                Essor Seguros S.A.     Uva  7.19       0   192.00  11429.00
# 30                Essor Seguros S.A.     Uva  5.39       0   192.00  12500.00
# 38                Essor Seguros S.A.     Uva  8.94       0   192.00  11429.00
# 46                Essor Seguros S.A.     Uva  8.83       0   192.00  11429.00
# ...                              ...     ...   ...     ...      ...       ...
# 183779  Tokio Marine Seguradora S.A.     Uva  0.50       0   179.00      0.00
# 195353  Tokio Marine Seguradora S.A.     Uva  0.60       0   142.00      0.00
# 195857  Tokio Marine Seguradora S.A.     Uva  0.64       0   139.00      0.00
# 200120  Tokio Marine Seguradora S.A.     Uva  2.52       0   284.00      0.00
# 205033    Mapfre Seguros Gerais S.A.     Uva  1.60       0   159.00  40000.00
#
#         prod_seg  total_seg   premio  taxa  subvencao  indenizacao  evento  \
# 13      11429.00  402501.01 50634.66  0.13   20253.86         0.00  nenhum
# 21      11429.00  369000.92 46420.31  0.13   18568.12         0.00  nenhum
# 30      12500.00  269600.00 33915.68  0.13   13566.27         0.00  nenhum
# 38      11429.00  355950.90 44778.65  0.13   17911.46         0.00  nenhum
# 46      11429.00  353500.89 44470.43  0.13   17788.17         0.00  nenhum
# ...          ...        ...      ...   ...        ...          ...     ...
# 183779      0.00   20000.00  1213.00  0.06     485.20         0.00  nenhum
# 195353      0.00   40050.00  4045.00  0.10    1618.00         0.00  nenhum
# 195857      0.00   40000.00  4040.00  0.10    1616.00         0.00  nenhum
# 200120      0.00  246960.00 16270.30  0.07    6508.12         0.00  nenhum
# 205033  40000.00   96000.00  5738.83  0.06    2295.53         0.00  nenhum
#
#         sinistro  sinistralidade
# 13             0            0.00
# 21             0            0.00
# 30             0            0.00
# 38             0            0.00
# 46             0            0.00
# ...          ...             ...
# 183779         0            0.00
# 195353         0            0.00
# 195857         0            0.00
# 200120         0            0.00
# 205033         0            0.00
#
# [9156 rows x 20 columns]

# %%
#organizando os valores pelo menor premio
df.sort_values(by='premio').head(10)
# Out:
#               apolice  cod_mun  municipio  uf      tipo_prod  \
# 173264  1000100057010  3149101   Pedralva  MG  produtividade
# 202101         152660  3139409   Manhuaçu  MG        custeio
# 135427  1000111091873  3128105      Guapé  MG  produtividade
# 170271  1000100056630  3125200       Fama  MG  produtividade
# 4785    6609001933201  3144003      Mutum  MG        custeio
# 152506  1000111093183  3130507   Ilicínea  MG  produtividade
# 158564  1000100056453  3147204  Paraguaçu  MG  produtividade
# 157219  1000100056840  3147204  Paraguaçu  MG  produtividade
# 163540  1000111094105  3103702   Araponga  MG  produtividade
# 172298  1000100056694  3147204  Paraguaçu  MG  produtividade
#
#                                      seguradora cultura  area  animal  \
# 173264  FairFax Brasil Seguros Corporativos S/A    Café  0.60       0
# 202101           BRASILSEG COMPANHIA DE SEGUROS    Café  0.10       0
# 135427            Sancor Seguros do Brasil S.A.    Café  0.28       0
# 170271  FairFax Brasil Seguros Corporativos S/A    Café  0.38       0
# 4785                 Mapfre Seguros Gerais S.A.    Café  1.00       0
# 152506            Sancor Seguros do Brasil S.A.    Café  0.80       0
# 158564  FairFax Brasil Seguros Corporativos S/A    Café  2.04       0
# 157219  FairFax Brasil Seguros Corporativos S/A    Café  2.56       0
# 163540            Sancor Seguros do Brasil S.A.    Café  1.00       0
# 172298  FairFax Brasil Seguros Corporativos S/A    Café  1.72       0
#
#         duracao  prod_est  prod_seg  total_seg  premio  taxa  subvencao  \
# 173264   303.00      0.00      0.00    8100.00   55.34  0.01      22.14
# 202101   365.00   3250.00   2275.00    1522.89   66.38  0.04      26.55
# 135427   366.00      0.00      0.00    1680.00   71.40  0.04      28.56
# 170271   320.00      0.00      0.00    6498.00   99.95  0.02      39.98
# 4785     365.00      0.00      0.00    7000.00  100.00  0.01      40.00
# 152506   366.00      0.00      0.00    6666.00  101.25  0.02      40.50
# 158564   327.00      0.00      0.00    6939.00  106.74  0.02      42.70
# 157219   351.00      0.00      0.00    7902.00  121.55  0.02      48.62
# 163540   366.00      0.00      0.00    8800.00  132.00  0.01      52.80
# 172298   309.00      0.00      0.00    9288.00  142.87  0.02      57.15
#
#         indenizacao  evento  sinistro  sinistralidade
# 173264         0.00  nenhum         0            0.00
# 202101         0.00  nenhum         0            0.00
# 135427         0.00  nenhum         0            0.00
# 170271         0.00  nenhum         0            0.00
# 4785           0.00  nenhum         0            0.00
# 152506         0.00  nenhum         0            0.00
# 158564         0.00  nenhum         0            0.00
# 157219         0.00  nenhum         0            0.00
# 163540         0.00  nenhum         0            0.00
# 172298         0.00  nenhum         0            0.00

# %%
#ordenando as apolices de forma decrescente de prêmio
#mostrando apenas algumas variáveis
df.loc[:, ['municipio', 'uf', 'cultura', 'premio']].sort_values(by='premio', ascending=False).head(10)
#entre as apolices com 10 maiores valores de premio, 7 são de soja.
# Out:
#            municipio  uf         cultura    premio
# 204736        Guaraí  TO            Soja 893218.14
# 108643       Vacaria  RS            Maçã 803274.07
# 201229        Gaspar  SC            Soja 761325.53
# 201428       Mirador  MA            Soja 655741.07
# 201663     Bom Jesus  PI  Milho 1ª safra 645849.04
# 51000   Campo Mourão  PR           Trigo 637102.44
# 201384      Estreito  MA            Soja 615490.60
# 188998        Loreto  MA            Soja 605418.48
# 152212   Santa Luzia  MA            Soja 568130.06
# 204779     Jaborandi  BA            Soja 529462.97

# %%
#COMEÇANDO OS GRÁFICOS
#podemos usar: 
#histogramas, kde (kernel density estimation) gráficos para estimar as distribuições de probabilidade, boxplots, para variáveis QUANTITATIVAS
#gráficos de colunas, barras, linhas, pizza, para variáveis QUALITATIVAS
pd.DataFrame(df['cultura'].value_counts(ascending=False))
# Out:
#                 count
# cultura
# Soja            99880
# Milho 2ª safra  37428
# Trigo           14790
# Milho 1ª safra  13150
# Café            12351
# ...               ...
# Couve-flor          2
# Melão               2
# Cacau               2
# Pastagem            2
# Girassol            1
#
# [64 rows x 1 columns]

# %%
#quantidade de apolices por cultura
df['cultura'].value_counts(ascending=True).plot.barh()
# Out:
# <Axes: ylabel='cultura'>

# %%
#mostrando apenas as 20 culturas mais seguradas
culturas = df['cultura'].value_counts(ascending=True)
culturas.tail(20).plot.barh()
# Out:
# <Axes: ylabel='cultura'>

# %%
#definindo um objeto ax para adicionar mais elementos ao gráfico
ax = df['cultura'].value_counts(ascending=True)\
    .tail(10)\
    .plot(kind='barh', title='10 culturas com mais apólices', color = 'purple')
ax.set_xlabel('Cultura')
ax.set_ylabel('Quantidade apólices')
# Out:
# Text(0, 0.5, 'Quantidade apólices')

# %%
#a porcentagem de apólices de soja é 46,9%
ax = df['cultura'].value_counts()\
    .plot(kind='pie', autopct='%1.1f%%',title='10 culturas com mais apólices (%)')
ax.set_xlabel(' ')
ax.set_ylabel(' ')
# Out:
# Text(0, 0.5, ' ')

# %%
#caso queiramos considerar apenas as 10 principais culturas
#vamos perder alguma informação sobre as porcentagens
ax = df['cultura'].value_counts()\
    .head(10)\
    .plot(kind='pie', autopct='%1.1f%%',title='10 culturas com mais apólices (%)')
ax.set_xlabel(' ')
ax.set_ylabel(' ')
# Out:
# Text(0, 0.5, ' ')

# %%
#afim de diminuir a quantidade de categorias
#vamos categorizar as culturas em classificações generalizantes
df['cultura'].unique()
# Out:
# array(['Milho 2ª safra', 'Uva', 'Tomate', 'Feijão 1ª safra', 'Sorgo',
#        'Café', 'Trigo', 'Feijão 2ª safra', 'Milho 1ª safra', 'Repolho',
#        'Tangerina', 'Atemoia', 'Pecuário', 'Floresta', 'Pepino',
#        'Cana-de-açúcar', 'Pimentão', 'Soja', 'Abobrinha', 'Alho',
#        'Berinjela', 'Beterraba', 'Canola', 'Melancia', 'Abóbora',
#        'Batata', 'Aveia', 'Cebola', 'Abacate', 'Couve-flor', 'Laranja',
#        'Triticale', 'Cenoura', 'Goiaba', 'Cevada', 'Banana', 'Ervilha',
#        'Pêssego', 'Ameixa', 'Amendoim', 'Mandioca', 'Maracujá',
#        'Brócolis', 'Alface', 'Caqui', 'Nectarina', 'Mamão', 'Kiwi',
#        'Vagem', 'Maçã', 'Arroz', 'Abacaxi', 'Lichia', 'Manga', 'Morango',
#        'Chuchu', 'Pêra', 'Limão', 'Algodão', 'Girassol', 'Figo', 'Cacau',
#        'Melão', 'Pastagem'], dtype=object)

# %%
#classificando os tipos de culturas
df['tipo_cultura'] = df['cultura'].replace({ 'Milho 2ª safra': 'cereais',
                                             'Uva': 'frutas', 
                                             'Tomate': 'frutas', 
                                             'Feijão 1ª safra': 'leguminosas', 
                                             'Sorgo': 'cereais',
                                             'Café': 'perene', 
                                             'Trigo': 'cereais', 
                                             'Feijão 2ª safra':'leguminosas' , 
                                             'Milho 1ª safra':'cereais', 
                                             'Repolho':'vegetais',
                                             'Tangerina':'frutas', 
                                             'Atemoia':'frutas', 
                                             'Pecuário':'pecuario', 
                                             'Floresta':'floresta', 
                                             'Pepino':'vegetais',
                                             'Cana-de-açúcar':'acucar', 
                                             'Pimentão':'frutas', 
                                             'Soja':'cereais', 
                                             'Abobrinha':'vegetais', 
                                             'Alho':'perene',
                                             'Berinjela':'frutas', 
                                             'Beterraba':'legume', 
                                             'Canola':'vegetais', 
                                             'Melancia':'frutas', 
                                             'Abóbora':'vegetais',
                                             'Batata':'legume', 
                                             'Aveia':'cereais',
                                             'Cebola':'legume', 
                                             'Abacate':'frutas', 
                                             'Couve-flor':'vegetais', 
                                             'Laranja':'frutas',
                                             'Triticale':'cereais', 
                                             'Cenoura':'legume', 
                                             'Goiaba':'frutas', 
                                             'Cevada':'cereais', 
                                             'Banana':'frutas', 
                                             'Ervilha':'leguminosas',
                                             'Pêssego':'frutas', 
                                             'Ameixa':'frutas', 
                                             'Amendoim':'leguminosas', 
                                             'Mandioca':'legume', 
                                             'Maracujá':'frutas',
                                             'Brócolis':'vegetais', 
                                             'Alface':'vegetais', 
                                             'Caqui':'frutas', 
                                             'Nectarina':'frutas',
                                             'Mamão':'frutas', 
                                             'Kiwi':'frutas',
                                             'Vagem':'leguminosas', 
                                             'Maçã':'frutas', 
                                             'Arroz':'cereais',
                                             'Abacaxi':'frutas', 
                                             'Lichia':'frutas',
                                             'Manga':'frutas', 
                                             'Morango':'frutas',
                                             'Chuchu':'legume', 
                                             'Pêra':'frutas', 
                                             'Limão':'frutas',
                                             'Algodão':'perene',
                                             'Girassol':'cereais',
                                             'Figo':'frutas', 
                                             'Cacau':'frutas',
                                             'Melão':'frutas',
                                             'Pastagem':'pastagem'
    
})

# %%
df['tipo_cultura'].unique()
# Out:
# array(['cereais', 'frutas', 'leguminosas', 'perene', 'vegetais',
#        'pecuario', 'floresta', 'acucar', 'legume', 'pastagem'],
#       dtype=object)

# %%
#colocando no gráfico a nova visualização
#valores totais
ax = df['tipo_cultura'].value_counts(ascending=True)\
    .plot(kind='barh', title='10 tipos de culturas com mais apólices', color = 'purple')
ax.set_xlabel('Quantidade Apólices')
ax.set_ylabel('Tipo Cultura')
# Out:
# Text(0, 0.5, 'Tipo Cultura')

# %%
#valores em porcentagem
ax = df['tipo_cultura'].value_counts(normalize=True, ascending=True)\
    .plot(kind='barh', title='10 tipos de culturas com mais apólices', color = 'purple')
ax.set_xlabel('Quantidade Apólices')
ax.set_ylabel('Tipo Cultura')
# Out:
# Text(0, 0.5, 'Tipo Cultura')

# %%
#colocando no gráfico a nova visualização
ax = df['tipo_cultura'].value_counts()\
    .plot(kind='pie', autopct='%1.1f%%',title='10 culturas com mais apólices (%)')
ax.set_xlabel(' ')
ax.set_ylabel(' ')
# Out:
# Text(0, 0.5, ' ')

# %%
#reoganizando as colunas no data frame
df = df.loc[:,['apolice', 'cod_mun', 'municipio', 'uf', 'tipo_prod','tipo_cultura', 'seguradora',
            'cultura', 'area', 'animal', 'duracao', 'prod_est', 'prod_seg', 'total_seg', 'premio',
            'taxa', 'subvencao', 'indenizacao', 'evento', 'sinistro', 'sinistralidade']]

# %%
#algumas variáveis quantitativas
#histograma
ax = df['premio'].plot(kind='hist', bins=20)
ax.set_ylabel('Número de Apólices')
ax.set_xlabel('Valor Prêmio (R$mil)')

#OBS: a maior parte das apólices são de pequenos valores segurados.
# Out:
# Text(0.5, 0, 'Valor Prêmio (R$mil)')

# %%
#olhando as apolices com valores maiores do que R$ 40 mil
premio = df[df['premio'] > 40000]
ax = premio['premio'].plot(kind='hist', bins=20)

# %%
#olhando as apolices com valores maiores do que R$ 400 mil
premio = df[df['premio'] > 400000]
ax = premio['premio'].plot(kind='hist', bins=20)

#Conforme aumentamos o valor das apólices, podemos verificar que a ocorrência de apólices diminui
#ou seja, quanto maior o valor, temos menos apólices

# %%
#o gráfico da distribuição feita no histograma, mas suavizada
ax = df['premio'].plot(kind='kde')

# %%
#com um box plot, podemos ver isso melhor
sns.boxplot(x=df['premio'], )
#a quantidade de outliers é alta, ou seja temos vários valores
#que não estão presentes na maior quantidade de ocorrências dos dados.
# Out:
# <Axes: xlabel='premio'>

# %%
#explorando os outliers 
#o valor de 22598.85 é referente ao 3º quartil da variável premio
#ou seja, 75% dos dados são valores de apólices abaixo de R$ 22598.85
premio = df[df['premio'] > 22598.85]
premio.shape #são 53210 ocorrências de valores maiores de 22598.85, lembrando que o valor máximo é quase 900000.00
# Out:
# (53210, 21)

# %%
#colocando no gráfico as principais culturas com "valores altos"(acima de 22598.85 até 890000) 
ax = premio['cultura'].value_counts()\
    .plot(kind='pie', autopct='%1.1f%%',title='Culturas (%)')
ax.set_xlabel(' ')
ax.set_ylabel(' ')

#das 53 mil ocorrências de "valores altos" 53.8% delas, ainda é de soja.
# Out:
# Text(0, 0.5, ' ')

# %%
#explorando os outliers 
#o valor de 22598.85 é referente ao 3º quartil da variável premio
#ou seja, 75% dos dados são valores de apólices abaixo de R$ 22598.85
premio = df[df['premio'] < 22598.85]
premio.shape #são 159629 ocorrências de valores menores de 22598.85
# Out:
# (159629, 21)

# %%
#colocando no gráfico as principais culturas com "valores baixos"(abaixo de 22598.85) 
ax = premio['cultura'].value_counts()\
    .plot(kind='pie', autopct='%1.1f%%',title='Culturas (%)')
ax.set_xlabel(' ')
ax.set_ylabel(' ')

#das 159629 mil ocorrências de "valores baixos" , 44.6% é de soja
# Out:
# Text(0, 0.5, ' ')

# %%
premio_baixo = df[df['premio'] < 22598.85]
premio_baixo['premio'].sum() #são 159629 ocorrências de valores menores de 22598.85
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[127], line 3
#       1 premio_baixo = df[df['premio'] < 22598.85]
#       2 premio_baixo_soma = premio_baixo['premio'].sum() #são 159629 ocorrências de valores menores de 22598.85
# ----> 3 premio_baixo_soma.plot()
#
# AttributeError: 'numpy.float64' object has no attribute 'plot'

# %%
premio_alto = df[df['premio'] > 22598.85]
premio_alto['premio'].sum() #são 53210 ocorrências de valores maiores de 22598.85

# %%
#function from: https://matplotlib.org/stable/users/explain/quick_start.html#quick-start
#função caso precise fazer as mesmas plotagens com dados diferentes
#data1 = seg[['VL_PREMIO_LIQUIDO', 'VL_SUBVENCAO_FEDERAL', 'NR_AREA_TOTAL']].quantile([0.25, 0.5, 0.75])
#data2 = seg[[

#def my_plotter(ax, data1, data2, param_dict):
#    """
#    A helper function to make a graph.
#    """
#    out = ax.plot(data1, data2, **param_dict)
#    return out


#data1, data2, data3, data4 = np.random.randn(4, 100)  # make 4 random data sets
#fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 2.7))
#my_plotter(ax1, data1, data2, {'marker': 'x'})
#my_plotter(ax2, data3, data4, {'marker': 'o'})
